# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Data\SupervisedLearningWShop\titanic.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 Cabin Embarked     Fare  Pclass            Ticket   Age  \
# 0           0   NaN        S   7.2500       3         A/5 21171  22.0
# 1           1   C85        C  71.2833       1          PC 17599  38.0
# 2           2   NaN        S   7.9250       3  STON/O2. 3101282  26.0
# 3           3  C123        S  53.1000       1            113803  35.0
# 4           4   NaN        S   8.0500       3            373450  35.0
#
#                                                 Name  Parch     Sex  SibSp  \
# 0                            Braund, Mr. Owen Harris      0    male      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0  female      1
# 2                             Heikkinen, Miss. Laina      0  female      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0  female      1
# 4                           Allen, Mr. William Henry      0    male      0
#
#    Survived
# 0       0.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       0.0

# %%
df.Age
# Out:
# 0       22.0
# 1       38.0
# 2       26.0
# 3       35.0
# 4       35.0
#         ...
# 1304     NaN
# 1305    39.0
# 1306    38.5
# 1307     NaN
# 1308     NaN
# Name: Age, Length: 1309, dtype: float64

# %%
df["Age"]
# Out:
# 0       22.0
# 1       38.0
# 2       26.0
# 3       35.0
# 4       35.0
#         ...
# 1304     NaN
# 1305    39.0
# 1306    38.5
# 1307     NaN
# 1308     NaN
# Name: Age, Length: 1309, dtype: float64

# %%
df[['Name', 'Parch', 'Sex']]
# Out:
#                                                    Name  Parch     Sex
# 0                               Braund, Mr. Owen Harris      0    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...      0  female
# 2                                Heikkinen, Miss. Laina      0  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)      0  female
# 4                              Allen, Mr. William Henry      0    male
# ...                                                 ...    ...     ...
# 1304                                 Spector, Mr. Woolf      0    male
# 1305                       Oliva y Ocana, Dona. Fermina      0  female
# 1306                       Saether, Mr. Simon Sivertsen      0    male
# 1307                                Ware, Mr. Frederick      0    male
# 1308                           Peter, Master. Michael J      1    male
#
# [1309 rows x 3 columns]

# %%
# first row
df.iloc[0]
# Out:
# Unnamed: 0                          0
# Cabin                             NaN
# Embarked                            S
# Fare                             7.25
# Pclass                              3
# Ticket                      A/5 21171
# Age                                22
# Name          Braund, Mr. Owen Harris
# Parch                               0
# Sex                              male
# SibSp                               1
# Survived                            0
# Name: 0, dtype: object

# %%
# first 3 rows
df.iloc[[0,1,2]]
# Out:
#    Unnamed: 0 Cabin Embarked     Fare  Pclass            Ticket   Age  \
# 0           0   NaN        S   7.2500       3         A/5 21171  22.0
# 1           1   C85        C  71.2833       1          PC 17599  38.0
# 2           2   NaN        S   7.9250       3  STON/O2. 3101282  26.0
#
#                                                 Name  Parch     Sex  SibSp  \
# 0                            Braund, Mr. Owen Harris      0    male      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0  female      1
# 2                             Heikkinen, Miss. Laina      0  female      0
#
#    Survived
# 0       0.0
# 1       1.0
# 2       1.0

# %%
columns = df.columns # Extract the list of columns
print(columns)
# Out:
# Index(['Unnamed: 0', 'Cabin', 'Embarked', 'Fare', 'Pclass', 'Ticket', 'Age',
#        'Name', 'Parch', 'Sex', 'SibSp', 'Survived'],
#       dtype='object')

# %%
df[columns[1:4]] # Columns 2, 3, 4
# Out:
#      Cabin Embarked      Fare
# 0      NaN        S    7.2500
# 1      C85        C   71.2833
# 2      NaN        S    7.9250
# 3     C123        S   53.1000
# 4      NaN        S    8.0500
# ...    ...      ...       ...
# 1304   NaN        S    8.0500
# 1305  C105        C  108.9000
# 1306   NaN        S    7.2500
# 1307   NaN        S    8.0500
# 1308   NaN        C   22.3583
#
# [1309 rows x 3 columns]

# %%
df['Fare'][2] # Column centric
# Out:
# 7.925

# %%
df.Fare[2] # Column centric
# Out:
# 7.925

# %%
child_passengers = df[df.Age  < 21][['Name', 'Age']]
child_passengers.head()
# Out:
#                                     Name   Age
# 7         Palsson, Master. Gosta Leonard   2.0
# 9    Nasser, Mrs. Nicholas (Adele Achem)  14.0
# 10       Sandstrom, Miss. Marguerite Rut   4.0
# 12        Saundercock, Mr. William Henry  20.0
# 14  Vestrom, Miss. Hulda Amanda Adolfina  14.0

# %%
print(len(child_passengers))
# Out:
# 249

# %%
young_adult_passengers = df.loc[
    (df.Age > 21) & (df.Age < 30)
]
len(young_adult_passengers)
# Out:
# 279

# %%
df.loc[
    (df.Pclass == 3) | (df.Pclass ==1)
]
# Out:
#       Unnamed: 0 Cabin Embarked      Fare  Pclass              Ticket   Age  \
# 0              0   NaN        S    7.2500       3           A/5 21171  22.0
# 1              1   C85        C   71.2833       1            PC 17599  38.0
# 2              2   NaN        S    7.9250       3    STON/O2. 3101282  26.0
# 3              3  C123        S   53.1000       1              113803  35.0
# 4              4   NaN        S    8.0500       3              373450  35.0
# ...          ...   ...      ...       ...     ...                 ...   ...
# 1304        1304   NaN        S    8.0500       3           A.5. 3236   NaN
# 1305        1305  C105        C  108.9000       1            PC 17758  39.0
# 1306        1306   NaN        S    7.2500       3  SOTON/O.Q. 3101262  38.5
# 1307        1307   NaN        S    8.0500       3              359309   NaN
# 1308        1308   NaN        C   22.3583       3                2668   NaN
#
# ...

# %%
df.loc[
    ~((df.Pclass == 3) | (df.Pclass == 1))
]
# Out:
#       Unnamed: 0 Cabin Embarked     Fare  Pclass         Ticket   Age  \
# 9              9   NaN        C  30.0708       2         237736  14.0
# 15            15   NaN        S  16.0000       2         248706  55.0
# 17            17   NaN        S  13.0000       2         244373   NaN
# 20            20   NaN        S  26.0000       2         239865  35.0
# 21            21   D56        S  13.0000       2         248698  34.0
# ...          ...   ...      ...      ...     ...            ...   ...
# 1278        1278   NaN        S  13.0000       2         244346  57.0
# 1284        1284   NaN        S  10.5000       2     C.A. 30769  47.0
# 1292        1292   NaN        S  21.0000       2          28664  38.0
# 1296        1296   D38        C  13.8625       2  SC/PARIS 2166  20.0
# 1297        1297   NaN        S  10.5000       2          28666  23.0
#
#                                               Name  Parch     Sex  SibSp  \
# ...

# %%
del df['Unnamed: 0']
df.head()
# Out:
#   Cabin Embarked     Fare  Pclass            Ticket   Age  \
# 0   NaN        S   7.2500       3         A/5 21171  22.0
# 1   C85        C  71.2833       1          PC 17599  38.0
# 2   NaN        S   7.9250       3  STON/O2. 3101282  26.0
# 3  C123        S  53.1000       1            113803  35.0
# 4   NaN        S   8.0500       3            373450  35.0
#
#                                                 Name  Parch     Sex  SibSp  \
# 0                            Braund, Mr. Owen Harris      0    male      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0  female      1
# 2                             Heikkinen, Miss. Laina      0  female      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0  female      1
# 4                           Allen, Mr. William Henry      0    male      0
#
#    Survived
# 0       0.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       0.0

# %%
df.head(n=20) # 20 lines
df.head(n=32) # 32 lines
# Out:
#           Cabin Embarked      Fare  Pclass            Ticket   Age  \
# 0           NaN        S    7.2500       3         A/5 21171  22.0
# 1           C85        C   71.2833       1          PC 17599  38.0
# 2           NaN        S    7.9250       3  STON/O2. 3101282  26.0
# 3          C123        S   53.1000       1            113803  35.0
# 4           NaN        S    8.0500       3            373450  35.0
# 5           NaN        Q    8.4583       3            330877   NaN
# 6           E46        S   51.8625       1             17463  54.0
# 7           NaN        S   21.0750       3            349909   2.0
# 8           NaN        S   11.1333       3            347742  27.0
# 9           NaN        C   30.0708       2            237736  14.0
# 10           G6        S   16.7000       3           PP 9549   4.0
# 11         C103        S   26.5500       1            113783  58.0
# 12          NaN        S    8.0500       3         A/5. 2151  20.0
# ...

# %%
df.describe()
# Out:
#               Fare       Pclass          Age        Parch        SibSp  \
# count  1308.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean     33.295479     2.294882    29.881138     0.385027     0.498854
# std      51.758668     0.837836    14.413493     0.865560     1.041658
# min       0.000000     1.000000     0.170000     0.000000     0.000000
# 25%       7.895800     2.000000    21.000000     0.000000     0.000000
# 50%      14.454200     3.000000    28.000000     0.000000     0.000000
# 75%      31.275000     3.000000    39.000000     0.000000     1.000000
# max     512.329200     3.000000    80.000000     9.000000     8.000000
#
#          Survived
# count  891.000000
# mean     0.383838
# std      0.486592
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      1.000000

# %%
df.count()
# Out:
# Cabin        295
# Embarked    1307
# Fare        1308
# Pclass      1309
# Ticket      1309
# Age         1046
# Name        1309
# Parch       1309
# Sex         1309
# SibSp       1309
# Survived     891
# dtype: int64

# %%
df.describe(include='all')
# Out:
#               Cabin Embarked         Fare       Pclass    Ticket          Age  \
# count           295     1307  1308.000000  1309.000000      1309  1046.000000
# unique          186        3          NaN          NaN       929          NaN
# top     C23 C25 C27        S          NaN          NaN  CA. 2343          NaN
# freq              6      914          NaN          NaN        11          NaN
# mean            NaN      NaN    33.295479     2.294882       NaN    29.881138
# std             NaN      NaN    51.758668     0.837836       NaN    14.413493
# min             NaN      NaN     0.000000     1.000000       NaN     0.170000
# 25%             NaN      NaN     7.895800     2.000000       NaN    21.000000
# 50%             NaN      NaN    14.454200     3.000000       NaN    28.000000
# 75%             NaN      NaN    31.275000     3.000000       NaN    39.000000
# max             NaN      NaN   512.329200     3.000000       NaN    80.000000
#
# ...

# %%
embarked_grouped = df.groupby('Embarked')
print(f'There are {len(embarked_grouped)} Embarked groups')
# Out:
# There are 3 Embarked groups

# %%
embarked_grouped.groups
# Out:
# {'C': [1, 9, 19, 26, 30, 31, 34, 36, 39, 42, 43, 48, 52, 54, 57, 60, 64, 65, 73, 96, 97, 111, 114, 118, 122, 125, 128, 130, 135, 139, 140, 155, 174, 177, 181, 194, 195, 203, 207, 209, 215, 218, 240, 244, 255, 256, 258, 273, 285, 291, 292, 295, 296, 299, 306, 307, 308, 309, 310, 311, 319, 325, 329, 337, 352, 354, 361, 362, 366, 367, 369, 370, 373, 375, 377, 378, 380, 381, 389, 393, 420, 448, 452, 453, 455, 469, 473, 484, 487, 493, 495, 496, 505, 513, 522, 523, 524, 531, 532, 533, ...], 'Q': [5, 16, 22, 28, 32, 44, 46, 47, 82, 109, 116, 126, 143, 156, 171, 186, 188, 196, 198, 208, 214, 241, 245, 260, 264, 274, 278, 280, 289, 300, 301, 303, 322, 330, 358, 359, 364, 368, 388, 411, 412, 421, 428, 459, 468, 501, 502, 510, 517, 525, 552, 560, 573, 593, 612, 613, 626, 629, 653, 654, 657, 680, 697, 703, 718, 727, 749, 767, 768, 776, 778, 787, 790, 825, 828, 885, 890, 891, 893, 897, 907, 938, 946, 954, 957, 961, 970, 975, 977, 979, 993, 997, 998, 1002, 1004, 1012, 1015, 1018, 1051, 1074, ...],
# ...

# %%
df.iloc[1]
# Out:
# Cabin                                                     C85
# Embarked                                                    C
# Fare                                                  71.2833
# Pclass                                                      1
# Ticket                                               PC 17599
# Age                                                        38
# Name        Cumings, Mrs. John Bradley (Florence Briggs Th...
# Parch                                                       0
# Sex                                                    female
# SibSp                                                       1
# Survived                                                    1
# Name: 1, dtype: object

# %%
for name, group in embarked_grouped:
    print(name, group.Age.mean())
# Out:
# C 32.33216981132075
# Q 28.63
# S 29.245204603580564

# %%
def first_val(x):
    return x.values[0]
embarked_grouped.agg(first_val)
# Out:
#          Cabin     Fare  Pclass     Ticket   Age  \
# Embarked
# C          C85  71.2833       1   PC 17599  38.0
# Q          NaN   8.4583       3     330877   NaN
# S          NaN   7.2500       3  A/5 21171  22.0
#
#                                                        Name  Parch     Sex  \
# Embarked
# C         Cumings, Mrs. John Bradley (Florence Briggs Th...      0  female
# Q                                          Moran, Mr. James      0    male
# S                                   Braund, Mr. Owen Harris      0    male
#
#           SibSp  Survived
# Embarked
# C             1       1.0
# Q             0       0.0
# S             1       0.0

# %%
embarked_grouped = df.groupby('Embarked')
embarked_grouped.agg(lambda x: x.values[0])
# Out:
#          Cabin     Fare  Pclass     Ticket   Age  \
# Embarked
# C          C85  71.2833       1   PC 17599  38.0
# Q          NaN   8.4583       3     330877   NaN
# S          NaN   7.2500       3  A/5 21171  22.0
#
#                                                        Name  Parch     Sex  \
# Embarked
# C         Cumings, Mrs. John Bradley (Florence Briggs Th...      0  female
# Q                                          Moran, Mr. James      0    male
# S                                   Braund, Mr. Owen Harris      0    male
#
#           SibSp  Survived
# Embarked
# C             1       1.0
# Q             0       0.0
# S             1       0.0

# %%
embarked_grouped.agg([lambda x: x.values[0], np.mean, np.std])
# Out:
#                Fare                           Pclass                      \
#          <lambda_0>       mean        std <lambda_0>      mean       std
# Embarked
# C           71.2833  62.336267  84.185996          1  1.851852  0.936802
# Q            8.4583  12.409012  13.616133          3  2.894309  0.380099
# S            7.2500  27.418824  37.096402          3  2.347921  0.784126
#
#                 Age                            Parch                      \
#          <lambda_0>       mean        std <lambda_0>      mean       std
# Embarked
# C              38.0  32.332170  15.258092          0  0.370370  0.670579
# Q               NaN  28.630000  15.045784          0  0.113821  0.531056
# S              22.0  29.245205  14.047507          0  0.426696  0.943989
#
#               SibSp                       Survived
#          <lambda_0>      mean       std <lambda_0>      mean       std
# Embarked
# C                 1  0.400000  0.554803        1.0  0.553571  0.498608
# ...

# %%
embarked_grouped.agg({
    'Fare': np.sum,
    'Age': lambda x: x.values[0]
})
# Out:
#                 Fare   Age
# Embarked
# C         16830.7922  38.0
# Q          1526.3085   NaN
# S         25033.3862  22.0

# %%
age_embarked_grouped = df.groupby(['Sex', 'Embarked'])
age_embarked_grouped.groups
# Out:
# {('male', 'S'): [0, 4, 6, 7, 12, 13, 17, 20, 21, 23, 27, 29, 33, 35, 37, 45, 50, 51, 55, 59, 62, 63, 67, 69, 70, 72, 74, 75, 76, 77, 78, 80, 81, 83, 86, 87, 89, 90, 91, 92, 93, 94, 95, 99, 101, 102, 103, 104, 105, 107, 108, 110, 112, 115, 117, 120, 121, 124, 127, 129, 131, 134, 137, 138, 144, 145, 146, 148, 149, 150, 152, 153, 154, 157, 158, 159, 160, 162, 163, 164, 165, 168, 169, 170, 173, 175, 176, 178, 179, 182, 183, 185, 187, 189, 191, 193, 197, 200, 201, 202, ...], ('female', 'C'): [1, 9, 19, 31, 39, 43, 52, 111, 114, 128, 140, 177, 194, 195, 215, 218, 240, 255, 256, 258, 291, 299, 306, 307, 309, 310, 311, 319, 325, 329, 337, 362, 366, 367, 369, 375, 380, 381, 389, 393, 448, 469, 473, 496, 513, 523, 533, 537, 539, 556, 578, 581, 591, 608, 641, 644, 691, 700, 702, 710, 716, 742, 780, 830, 835, 842, 849, 852, 858, 866, 874, 875, 879, 899, 906, 910, 915, 917, 939, 950, 965, 991, 995, 1003, 1013, 1041, 1059, 1070, 1075, 1099, 1109, 1111, 1115, 1116, 1130, 1131, 1140, 1163, 1174, 118
# ...

# %%
complete_data = df.dropna()
print(f'Total: {len(df)} , non NA {len(complete_data)}')
# Out:
# Total: 1309 , non NA 183

# %%
df.aggregate(lambda x: x.isna().sum() )
# Out:
# Cabin       1014
# Embarked       2
# Fare           1
# Pclass         0
# Ticket         0
# Age          263
# Name           0
# Parch          0
# Sex            0
# SibSp          0
# Survived     418
# dtype: int64

# %%
# Filter non NA
df_valid = df.loc[(~df.Embarked.isna()) & (~df.Fare.isna())]

# %%
# fill the mean
df_valid[['Age']] = df_valid[['Age']].fillna(df_valid.Age.mean())
# Out:
# C:\Tools\Anaconda3\envs\MachineLearningClassic\lib\site-packages\pandas\core\frame.py:3062: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
df_valid.loc[df.Pclass == 1, 'Age'].mean()
# Out:
# 37.956806510096975

# %%
for name, grp in df_valid.groupby(['Pclass', 'Sex']):
    print('%i' % name[0], name[1], '%0.2f' % grp['Age'].mean())
# Out:
# 1 female 36.30
# 1 male 39.27
# 2 female 27.56
# 2 male 30.74
# 3 female 24.45
# 3 male 27.02

# %%
# Transform per class
mean_ages = df_valid.groupby(['Pclass', 'Sex'])['Age'].\
    transform(lambda x: x.fillna(x.mean()))
df_valid.loc[:, 'Age'] = mean_ages
# Out:
# C:\Tools\Anaconda3\envs\MachineLearningClassic\lib\site-packages\pandas\core\indexing.py:1745: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %%
# Class imbalance
print(f' Survived:{len(df.loc[df.Survived ==1])} Not Survived:{len(df.loc[df.Survived ==0])}')
# Out:
#  Survived:342 Not Survived:549

# %%
# Append the first row of the data set
df_oversample = df.append(df.iloc[0])
